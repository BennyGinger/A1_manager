# %%
# Inject in the center, image on the bottom side
from a1_manager import A1Manager

import json
from pathlib import Path
from tifffile import imwrite
from time import sleep
from typing import Any

from a1_manager import A1Manager, launch_dish_workflow

# %%
from a1_manager.microscope_hardware.nanopick.devices.valve import PICController
controller = PICController(needle_size=50, pressure=0.3, port="COM9")

# %%
for j in range(4):
    # a1_manager = A1Manager(objective = '20x', lamp_name = 'pE-800', focus_device  = 'PFSOffset')
    # run_dir = Path('D:\\Zsuzsi\\20260421_fMLF_96_well\\C2')

    # a1_manager.oc_settings('GFP')

    well= 'C2'
    controller.inject(inject_vol_ul=10, mixing_cycles=3)

    # for i in range(2):

        # img = a1_manager.snap_image()
        # img_name = f"{well}_bottom_border_baseline{i}.tif"
        # imwrite(run_dir / img_name, img, compression='zlib')
        # print(f"Saved image {img_name}")

    # controller.inject(inject_vol_ul=10, mixing_cycles=3)

    # for i in range(2):

    #     img = a1_manager.snap_image()
    #     img_name = f"{well}_bottom_border_injection_{i}.tif"
    #     imwrite(run_dir / img_name, img, compression='zlib')
    #     print(f"Saved image {img_name}")
    #     #sleep(0.1)
